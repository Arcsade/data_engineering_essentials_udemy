# %%
orders_file = open('C:/Users/subha/Documents/GitHub/data_engineering_essentials_udemy/retail_db/orders/part-00000')

# %%
orders_str = orders_file.read()

# %%
type(orders_str)
# Out:
# str

# %%
len(orders_str.splitlines())
# Out:
# 68883

# %%
orders= orders_str.splitlines()

# %%
len(orders)
# all orders
# Out:
# 68883

# %%
orders[:10]
# first 10 records
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT']

# %%
orders[-10:]
# last 10 records
# Out:
# ['68874,2014-07-03 00:00:00.0,1601,COMPLETE',
#  '68875,2014-07-04 00:00:00.0,10637,ON_HOLD',
#  '68876,2014-07-06 00:00:00.0,4124,COMPLETE',
#  '68877,2014-07-07 00:00:00.0,9692,ON_HOLD',
#  '68878,2014-07-08 00:00:00.0,6753,COMPLETE',
#  '68879,2014-07-09 00:00:00.0,778,COMPLETE',
#  '68880,2014-07-13 00:00:00.0,1117,COMPLETE',
#  '68881,2014-07-19 00:00:00.0,2518,PENDING_PAYMENT',
#  '68882,2014-07-22 00:00:00.0,10000,ON_HOLD',
#  '68883,2014-07-23 00:00:00.0,5533,COMPLETE']

# %%
first_10_orders = orders[:10]  # adding first 10 records

# %%
first_10_orders[1]  # second record in the first 10 records
# Out:
# '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT'

# %%
s ={1,1,2,2,3,4,5,5} # set does not allow duplicates

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
orders_tuple = ('1','2013-07-25 00:00:00','11599','CLOSED') # tuple does not allow changes

# %%
orders_tuple
# Out:
# ('1', '2013-07-25 00:00:00', '11599', 'CLOSED')

# %%
orders_dict = {'order_id': '1', 'order_date': '2013-07-25 00:00:00', 'customer_id': '11599', 'order_status': 'CLOSED'} # dictionary key-value pair

# %%
orders_dict
# Out:
# {'order_id': '1',
#  'order_date': '2013-07-25 00:00:00',
#  'customer_id': '11599',
#  'order_status': 'CLOSED'}

# %%
orders_dict.keys()
# Out:
# dict_keys(['order_id', 'order_date', 'customer_id', 'order_status'])

# %%
orders_dict.values()
# Out:
# dict_values(['1', '2013-07-25 00:00:00', '11599', 'CLOSED'])

# %%
orders_dict['order_status'] # get value from dictionary this will throw error if key not found
# Out:
# 'CLOSED'

# %%
orders_dict.get('order_status') # another way to get value from dictionary this will return None if key not found
# Out:
# 'CLOSED'

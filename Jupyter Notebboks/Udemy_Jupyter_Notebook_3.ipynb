# %%
orders_json_data = "{\"order_id\": 1, \"order_date\": \"2023-01-01\", \"customer_id\": 101, \"status\": \"COMPLETE\"}" # JSON string

# %%
import json # import json module
orders = json.loads(orders_json_data) # parse JSON string to Python dictionary
orders
orders["order_date"] # access value by key
# Out:
# '2023-01-01'

# %%
orders_json_array = "[\"Dallas\", \"Austin\", \"San Francisco\"]" # JSON array string
cities = json.loads(orders_json_array) # parse JSON array string to Python list
cities
cities[1] # access list element by index
# Out:
# 'Austin'

# %%
schema_json = json.load(open("C:/Users/subha/Documents/GitHub/data_engineering_essentials_udemy/retail_db/schemas.json")) # parse JSON string to Python dictionary

# %%
schema_json.keys() # get all keys in the dictionary
# Out:
# dict_keys(['departments', 'categories', 'orders', 'products', 'customers', 'order_items'])

# %%
list(schema_json.keys()) # convert dict_keys to list
# Out:
# ['departments', 'categories', 'orders', 'products', 'customers', 'order_items']

# %%
schema_json.get('orders')   # get value by key with get() method
# Out:
# [{'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1},
#  {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#  {'column_name': 'order_customer_id',
#   'data_type': 'timestamp',
#   'column_position': 3},
#  {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %%
# get_column_names(schemas, key, sort by) --- IGNORE ---

# %%
orders_schema = schema_json.get('orders')

# %%
[col['column_name'] for col in orders_schema] # list comprehension to extract column names
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
list(map(lambda col: col['column_name'], orders_schema)) # use map and lambda to extract column names
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
sorting_key = input("Enter the sorting key (e.g., column_name, data_type): ")
sorted(orders_schema, key=lambda col: col[sorting_key]) # sort list of dictionaries by column_name key
# Out:
# [{'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1},
#  {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#  {'column_name': 'order_customer_id',
#   'data_type': 'timestamp',
#   'column_position': 3},
#  {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %%
def get_column_names(schemas, ds_name, sorting_key='column_name'):  # function to get column names for a given dataset sorted by a specified key
    column_details = schemas.get(ds_name) # get schema for the specified dataset
    columns = sorted(column_details, key=lambda col: col[sorting_key]) # sort columns by the specified key 
    return list(map(lambda col: col['column_name'], columns))  # or [col['column_name'] for col in columns] # extract and return column names

# %%
get_column_names(schema_json, 'orders','column_position')
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']
